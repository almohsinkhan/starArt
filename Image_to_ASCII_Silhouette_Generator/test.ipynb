# %%
import cv2

# Read an image
image = cv2.imread('example/dog.jpg')

# Display the image
cv2.imshow('My Image', image)
h, w, c  =  image.shape
print("hight : ", h )
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# hight :  452
